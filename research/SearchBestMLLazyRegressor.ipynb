# %% [markdown]
# # Import libs

# %% [markdown]
# ### Install a library that will brute force the best model

# %%
# !pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.12-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.5.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from lazypredict) (4.66.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.3.2)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (from lazypredict) (4.1.0)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (from lazypredict) (2.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lightgbm->lazypredict) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm->lazypredict) (1.11.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2023.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->lazypredict) (3.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->lazypredict) (1.16.0)
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.2.12

# %% [markdown]
# ### Import other libraries that will be used in this file

# %%
import pandas as pd
import numpy as np
from scipy import stats
from sklearn.svm import NuSVR
from sklearn.base import clone
from sklearn.model_selection import KFold
from sklearn.preprocessing import MaxAbsScaler
from sklearn.metrics import max_error, mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, median_absolute_error, r2_score
from gtm_steps import MultiLabelGTM

# %% [markdown]
# ### Code for simplification and convenient use of various models in the following file

# %%
class ModelStrategy(object):
    def __init__(self, regressor) -> None:
        self._strategy = regressor
        self._regressors = []

    def get_strategy(self):
        return self._strategy

    def get_regressors(self):
        return self._regressors

    def set_strategy(self, regressor) -> None:
        self._strategy = regressor

    def fit(self, X_train, Y_train) -> None:
        for y_train in Y_train.T:
            regressor = clone(self._strategy, safe=True)
            # Fit and save all regressors
            regressor.fit(X_train, y_train)
            self._regressors.append(regressor)

    def fit_transform(self, X_train, Y_train):
        y_train_pred = []
        for y_train in Y_train.T:
            regressor = clone(self._strategy, safe=True)
            # Fit and save all regressors
            regressor.fit(X_train, y_train)
            self._regressors.append(regressor)
            # Predict and save prediction for future use
            y_train_pred.append(regressor.predict(X_train))

        # Transfrom data to numpy array and return
        return np.stack(y_train_pred, axis=1)

    def transform(self, X):
        y_pred = []
        for regressor in self._regressors:
            # For each saved regressor predict an output value
            y_pred.append(regressor.predict(X))
        return np.stack(y_pred, axis=1)

class AdapterSGTM(object):
    def __init__(self, number_of_steps = 1000, verbose=0):
        self._gtm = MultiLabelGTM(number_of_steps = number_of_steps, center_of_mass = True, verbose=verbose)

    def fit(self, X_train) -> None:
        self._gtm.fit(X_train, X_train)

    def fit_transform(self, X_train):
        self._gtm.fit(X_train, X_train)
        return self._gtm.predict(X_train)

    def transform(self, X):
        return self._gtm.predict(X)


def relative_root_mean_squared_error(y, y_pred):
    n = len(y)
    num = np.sum(np.square(y - y_pred)) / n
    den = np.sum(np.square(y_pred))
    squared_error = num / den
    rrmse_loss = np.sqrt(squared_error)
    return rrmse_loss

def calculate_errors(y, y_pred):
    MaxError = max_error                         (y, y_pred)
    MedError = median_absolute_error             (y, y_pred)
    MAE = mean_absolute_error                    (y, y_pred)
    MAPE = mean_absolute_percentage_error        (y, y_pred)
    MSE = mean_squared_error                     (y, y_pred)
    RMSE = mean_squared_error                    (y, y_pred, squared=False)
    RRMSE = relative_root_mean_squared_error     (y, y_pred)
    R2 = r2_score                                (y, y_pred)

    return {
            'MaxError' : MaxError,
            'MedError' : MedError,
            'MAE' :      MAE,
            'MAPE' :     MAPE,
            'MSE' :      MSE,
            'RMSE' :     RMSE,
            'RRMSE' :    RRMSE,
            'R2' :       R2}

# %%
task_name = 'FullTask'

# %% [markdown]
# # Load data

# %% [markdown]
# ### The step in which all the data will be loaded and divided it into X (inputs) and Y (outputs, predictions)

# %%
data = pd.read_csv('/content/Tunneling_Induced_building_damage_dataset_V2.txt', sep='\t')
data = data.drop(labels = 'Number', axis=1)

data = data.drop(labels = [
    'Identifier',
    'Unnamed: 17',
    'Unnamed: 19',
    'Unnamed: 21',
    'Unnamed: 22',
    'Unnamed: 27',
    'Unnamed: 27',
    'Unnamed: 28',
    'Unnamed: 29',
    'Unnamed: 30',
    'Unnamed: 31'
], axis=1)

# remove outliers
data = data[(np.abs(stats.zscore(data.select_dtypes(exclude='object'))) < 3).all(axis=1)]
data_columns = data.columns
data.head()
X = data.iloc[:,:15].to_numpy()
if task_name == 'Task1':
    Y = data[['L. Average', 'G. Average']]
elif task_name == 'Task2':
    Y = data[['C. Width', 'Tot. Cracks ', 'Slope', 'Tilt', 'Ang. Dist.', 'Max Strain']]
else:
    Y = data[['C. Width', 'Tot. Cracks ', 'L. Average', 'Slope', 'Tilt', 'Ang. Dist.', 'Max Strain', 'G. Average']]
target_columns = Y.columns
Y = Y.to_numpy()

# %% [markdown]
# # Find First LazyRegressor

# %% [markdown]
# ### Brute force the first model for our data using LazyRegressor.
#
# * We use cross-validation
# * We save the obtained results

# %%
from lazypredict.Supervised import LazyRegressor

results = []

kf = KFold(n_splits=5, shuffle=True, random_state=42)
for train_index, test_index in kf.split(X, Y):
    X_train, X_test = X[train_index], X[test_index]
    Y_train, Y_test = Y[train_index], Y[test_index]

    scaler_x = MaxAbsScaler()
    scaler_y = MaxAbsScaler()

    X_train = scaler_x.fit_transform(X_train)
    Y_train = scaler_y.fit_transform(Y_train)

    X_test = scaler_x.transform(X_test)
    Y_test = scaler_y.transform(Y_test)

    for i, (y_train, y_test) in enumerate(zip(Y_train[:].T, Y_test[:].T)):
        print(f'Training: {target_columns[i]}')
        reg = LazyRegressor(verbose=-10,
                            ignore_warnings=True,
                            custom_metric=None,
                            predictions=True,
                            regressors='all')#regressors)
        models,predictions = reg.fit(X_train, X_test, y_train, y_test)
        results.append(models)

# %% [markdown]
# ### By using the saved results, the final is calculated accuracy for each output (rating of the models from the best to the worst Adjusted R-Squared metric)

# %%
sorted_results = []
for res in results:
  sorted_results.append(res.sort_values(by=['Model']))

sorted_results

final_results = {target : 0 for target in target_columns}

for i, res in enumerate(sorted_results):
    target = target_columns[i % len(target_columns)]
    final_results[target] = final_results[target] + res.to_numpy()

for target, final_res in final_results.items():
    final_res = final_res / 5
    final_results[target] = final_res

for i, target in enumerate(target_columns):
    print(f'Calculate: {target}')
    print(pd.DataFrame(final_results[target],
                 columns = sorted_results[i].columns,
                 index =   sorted_results[i].index
    ).sort_values(by=['Adjusted R-Squared'], ascending=False))
# Out:
# Calculate: C. Width
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# MLPRegressor                                 0.65       0.68  0.56        0.82
# NuSVR                                        0.62       0.65  0.59        0.11
# SVR                                          0.61       0.65  0.60        0.11
# HistGradientBoostingRegressor                0.59       0.62  0.61        1.12
# LGBMRegressor                                0.58       0.62  0.62        0.20
# ExtraTreesRegressor                          0.56       0.60  0.63        0.40
# XGBRegressor                                 0.53       0.57  0.65        0.76
# RandomForestRegressor                        0.53       0.57  0.66        0.82
# GradientBoostingRegressor                    0.50       0.55  0.67        0.63
# BaggingRegressor                             0.45       0.50  0.71        0.11
# BayesianRidge                                0.42       0.47  0.73        0.03
# RidgeCV                                      0.42       0.47  0.73        0.03
# LassoLarsIC                                  0.42       0.47  0.73        0.04
# Lars                                         0.42       0.47  0.73        0.03
# LassoCV                                      0.42       0.47  0.73        0.15
# Ridge                                        0.42       0.47  0.73        0.02
# KernelRidge                                  0.42       0.47  0.73        0.05
# TransformedTargetRegressor                   0.42       0.47  0.73        0.02
# LinearRegression                             0.42       0.47  0.73        0.03
# LarsCV                                       0.42       0.47  0.73        0.06
# LassoLarsCV                                  0.42       0.47  0.73        0.08
# ElasticNetCV                                 0.42       0.47  0.73        0.17
# SGDRegressor                                 0.42       0.47  0.73        0.03
# HuberRegressor                               0.40       0.45  0.74        0.03
# AdaBoostRegressor                            0.40       0.45  0.74        0.22
# KNeighborsRegressor                          0.39       0.44  0.74        0.02
# OrthogonalMatchingPursuitCV                  0.38       0.43  0.75        0.02
# LinearSVR                                    0.38       0.43  0.76        0.05
# TweedieRegressor                             0.35       0.40  0.77        0.16
# GaussianProcessRegressor                     0.20       0.27  0.85        0.09
# OrthogonalMatchingPursuit                    0.12       0.19  0.90        0.02
# DecisionTreeRegressor                        0.08       0.15  0.91        0.07
# PassiveAggressiveRegressor                   0.07       0.14  0.92        0.02
# ExtraTreeRegressor                           0.01       0.09  0.94        0.03
# ElasticNet                                  -0.10      -0.01  1.00        0.02
# DummyRegressor                              -0.10      -0.01  1.00        0.02
# LassoLars                                   -0.10      -0.01  1.00        0.02
# Lasso                                       -0.10      -0.01  1.00        0.02
# RANSACRegressor                             -0.29      -0.18  1.07        0.21
# Calculate: Tot. Cracks
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# MLPRegressor                                 0.73       0.75  0.50        0.82
# SVR                                          0.68       0.71  0.54        0.10
# NuSVR                                        0.68       0.71  0.54        0.12
# LGBMRegressor                                0.67       0.70  0.55        0.19
# HistGradientBoostingRegressor                0.67       0.70  0.55        0.40
# ExtraTreesRegressor                          0.64       0.67  0.57        0.32
# XGBRegressor                                 0.62       0.65  0.59        1.00
# RandomForestRegressor                        0.61       0.64  0.60        0.85
# GradientBoostingRegressor                    0.59       0.63  0.61        0.50
# BaggingRegressor                             0.57       0.60  0.63        0.09
# AdaBoostRegressor                            0.50       0.54  0.67        0.21
# KNeighborsRegressor                          0.46       0.51  0.70        0.02
# RidgeCV                                      0.45       0.50  0.71        0.03
# BayesianRidge                                0.45       0.50  0.71        0.02
# SGDRegressor                                 0.45       0.50  0.71        0.03
# LassoLarsIC                                  0.45       0.50  0.71        0.03
# KernelRidge                                  0.45       0.50  0.71        0.05
# Ridge                                        0.45       0.50  0.71        0.01
# Lars                                         0.45       0.50  0.71        0.04
# TransformedTargetRegressor                   0.45       0.50  0.71        0.02
# LinearRegression                             0.45       0.50  0.71        0.03
# ElasticNetCV                                 0.45       0.49  0.71        0.12
# LassoCV                                      0.45       0.49  0.71        0.15
# LassoLarsCV                                  0.45       0.49  0.71        0.08
# LarsCV                                       0.45       0.49  0.71        0.07
# HuberRegressor                               0.41       0.46  0.73        0.03
# LinearSVR                                    0.38       0.43  0.75        0.05
# OrthogonalMatchingPursuitCV                  0.38       0.43  0.75        0.02
# TweedieRegressor                             0.36       0.41  0.77        0.16
# GaussianProcessRegressor                     0.28       0.34  0.81        0.08
# DecisionTreeRegressor                        0.17       0.24  0.87        0.05
# OrthogonalMatchingPursuit                    0.11       0.18  0.90        0.02
# ExtraTreeRegressor                           0.03       0.11  0.93        0.02
# DummyRegressor                              -0.10      -0.01  1.00        0.02
# LassoLars                                   -0.10      -0.01  1.00        0.03
# Lasso                                       -0.10      -0.01  1.00        0.03
# ElasticNet                                  -0.10      -0.01  1.00        0.02
# PassiveAggressiveRegressor                  -0.44      -0.33  1.14        0.02
# RANSACRegressor                             -0.86      -0.71  1.27        0.19
# Calculate: L. Average
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# MLPRegressor                                 0.78       0.80  0.45        0.83
# SVR                                          0.74       0.76  0.49        0.09
# NuSVR                                        0.74       0.76  0.49        0.11
# HistGradientBoostingRegressor                0.71       0.74  0.51        0.91
# LGBMRegressor                                0.70       0.73  0.52        0.19
# ExtraTreesRegressor                          0.66       0.69  0.56        0.40
# GradientBoostingRegressor                    0.64       0.67  0.58        0.60
# RandomForestRegressor                        0.63       0.66  0.58        0.83
# XGBRegressor                                 0.63       0.66  0.58        0.52
# BaggingRegressor                             0.58       0.61  0.62        0.11
# AdaBoostRegressor                            0.52       0.56  0.66        0.21
# SGDRegressor                                 0.52       0.56  0.66        0.03
# BayesianRidge                                0.52       0.56  0.66        0.02
# LassoLarsIC                                  0.52       0.56  0.66        0.03
# RidgeCV                                      0.52       0.56  0.66        0.03
# KernelRidge                                  0.52       0.56  0.66        0.04
# Ridge                                        0.52       0.56  0.66        0.01
# LinearRegression                             0.52       0.56  0.66        0.03
# TransformedTargetRegressor                   0.52       0.56  0.66        0.02
# ElasticNetCV                                 0.52       0.56  0.66        0.15
# LassoCV                                      0.52       0.56  0.66        0.14
# LassoLarsCV                                  0.52       0.56  0.66        0.08
# HuberRegressor                               0.51       0.55  0.67        0.03
# LinearSVR                                    0.50       0.54  0.68        0.05
# KNeighborsRegressor                          0.49       0.53  0.68        0.02
# LarsCV                                       0.48       0.52  0.69        0.07
# Lars                                         0.46       0.50  0.70        0.03
# OrthogonalMatchingPursuitCV                  0.45       0.50  0.71        0.02
# TweedieRegressor                             0.42       0.47  0.73        0.07
# GaussianProcessRegressor                     0.26       0.33  0.82        0.10
# DecisionTreeRegressor                        0.20       0.27  0.85        0.06
# ExtraTreeRegressor                           0.16       0.23  0.87        0.03
# OrthogonalMatchingPursuit                    0.16       0.23  0.88        0.01
# DummyRegressor                              -0.10      -0.01  1.00        0.03
# LassoLars                                   -0.10      -0.01  1.00        0.02
# Lasso                                       -0.10      -0.01  1.00        0.02
# ElasticNet                                  -0.10      -0.01  1.00        0.02
# PassiveAggressiveRegressor                  -0.24      -0.14  1.05        0.01
# RANSACRegressor                             -0.97      -0.81  1.27        0.21
# Calculate: Slope
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# MLPRegressor                                 0.88       0.89  0.33        0.82
# NuSVR                                        0.87       0.88  0.34        0.13
# HistGradientBoostingRegressor                0.87       0.88  0.34        0.40
# SVR                                          0.87       0.88  0.34        0.10
# LGBMRegressor                                0.87       0.88  0.34        0.19
# GradientBoostingRegressor                    0.85       0.86  0.37        0.48
# ExtraTreesRegressor                          0.84       0.86  0.37        0.41
# XGBRegressor                                 0.84       0.85  0.38        0.83
# RandomForestRegressor                        0.82       0.83  0.40        0.93
# BaggingRegressor                             0.79       0.81  0.44        0.09
# LassoLarsIC                                  0.70       0.73  0.52        0.04
# LarsCV                                       0.70       0.73  0.52        0.07
# ElasticNetCV                                 0.70       0.73  0.52        0.13
# LassoCV                                      0.70       0.73  0.52        0.15
# LassoLarsCV                                  0.70       0.73  0.52        0.07
# RidgeCV                                      0.70       0.73  0.52        0.04
# BayesianRidge                                0.70       0.73  0.52        0.02
# KernelRidge                                  0.70       0.73  0.52        0.04
# Ridge                                        0.70       0.73  0.52        0.02
# LinearRegression                             0.70       0.73  0.52        0.03
# Lars                                         0.70       0.73  0.52        0.03
# TransformedTargetRegressor                   0.70       0.73  0.52        0.02
# SGDRegressor                                 0.70       0.73  0.52        0.03
# AdaBoostRegressor                            0.70       0.72  0.52        0.21
# HuberRegressor                               0.70       0.72  0.52        0.03
# OrthogonalMatchingPursuitCV                  0.70       0.72  0.52        0.03
# LinearSVR                                    0.69       0.72  0.53        0.05
# DecisionTreeRegressor                        0.63       0.66  0.58        0.05
# KNeighborsRegressor                          0.59       0.62  0.61        0.02
# TweedieRegressor                             0.58       0.61  0.62        0.11
# RANSACRegressor                              0.56       0.60  0.62        0.19
# ExtraTreeRegressor                           0.52       0.56  0.66        0.03
# PassiveAggressiveRegressor                   0.46       0.50  0.70        0.02
# GaussianProcessRegressor                     0.27       0.33  0.81        0.08
# OrthogonalMatchingPursuit                    0.11       0.18  0.90        0.01
# ElasticNet                                  -0.09      -0.00  1.00        0.02
# LassoLars                                   -0.10      -0.01  1.00        0.02
# Lasso                                       -0.10      -0.01  1.00        0.04
# DummyRegressor                              -0.10      -0.01  1.00        0.03
# Calculate: Tilt
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# MLPRegressor                                 0.87       0.88  0.34        0.82
# NuSVR                                        0.86       0.87  0.35        0.13
# SVR                                          0.86       0.87  0.35        0.10
# HistGradientBoostingRegressor                0.86       0.87  0.35        0.85
# LGBMRegressor                                0.86       0.87  0.36        0.19
# ExtraTreesRegressor                          0.84       0.85  0.38        0.50
# GradientBoostingRegressor                    0.84       0.85  0.38        0.63
# XGBRegressor                                 0.83       0.85  0.39        0.50
# RandomForestRegressor                        0.81       0.82  0.42        0.82
# BaggingRegressor                             0.79       0.80  0.44        0.10
# RidgeCV                                      0.69       0.72  0.53        0.03
# BayesianRidge                                0.69       0.72  0.53        0.02
# ElasticNetCV                                 0.69       0.72  0.53        0.17
# LassoCV                                      0.69       0.72  0.53        0.14
# LarsCV                                       0.69       0.72  0.53        0.05
# LassoLarsCV                                  0.69       0.72  0.53        0.07
# Ridge                                        0.69       0.72  0.53        0.01
# KernelRidge                                  0.69       0.72  0.53        0.04
# SGDRegressor                                 0.69       0.72  0.53        0.02
# TransformedTargetRegressor                   0.69       0.72  0.53        0.02
# LinearRegression                             0.69       0.72  0.53        0.02
# Lars                                         0.69       0.72  0.53        0.03
# LassoLarsIC                                  0.69       0.72  0.53        0.03
# HuberRegressor                               0.69       0.71  0.53        0.03
# OrthogonalMatchingPursuitCV                  0.69       0.71  0.53        0.02
# AdaBoostRegressor                            0.68       0.71  0.53        0.21
# LinearSVR                                    0.68       0.71  0.54        0.03
# DecisionTreeRegressor                        0.66       0.69  0.56        0.06
# KNeighborsRegressor                          0.58       0.62  0.62        0.02
# TweedieRegressor                             0.56       0.60  0.63        0.08
# RANSACRegressor                              0.50       0.54  0.67        0.21
# ExtraTreeRegressor                           0.49       0.53  0.68        0.03
# PassiveAggressiveRegressor                   0.37       0.43  0.75        0.01
# GaussianProcessRegressor                     0.27       0.33  0.82        0.12
# OrthogonalMatchingPursuit                    0.10       0.18  0.90        0.01
# ElasticNet                                  -0.10      -0.01  1.00        0.03
# DummyRegressor                              -0.10      -0.01  1.00        0.03
# LassoLars                                   -0.10      -0.01  1.00        0.02
# Lasso                                       -0.10      -0.01  1.00        0.02
# Calculate: Ang. Dist.
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# MLPRegressor                                 0.80       0.82  0.43        0.84
# LGBMRegressor                                0.72       0.75  0.50        0.18
# NuSVR                                        0.71       0.74  0.51        0.13
# SVR                                          0.71       0.74  0.51        0.12
# HistGradientBoostingRegressor                0.71       0.74  0.51        0.40
# ExtraTreesRegressor                          0.69       0.72  0.53        0.40
# XGBRegressor                                 0.68       0.70  0.54        0.79
# RandomForestRegressor                        0.66       0.69  0.56        1.06
# GradientBoostingRegressor                    0.64       0.67  0.57        0.50
# BaggingRegressor                             0.62       0.66  0.58        0.10
# LarsCV                                       0.48       0.53  0.69        0.07
# BayesianRidge                                0.48       0.53  0.69        0.02
# RidgeCV                                      0.48       0.53  0.69        0.03
# KernelRidge                                  0.48       0.53  0.69        0.05
# Ridge                                        0.48       0.53  0.69        0.02
# ElasticNetCV                                 0.48       0.53  0.69        0.13
# TransformedTargetRegressor                   0.48       0.53  0.69        0.02
# Lars                                         0.48       0.53  0.69        0.03
# LinearRegression                             0.48       0.53  0.69        0.03
# LassoLarsIC                                  0.48       0.53  0.69        0.03
# LassoCV                                      0.48       0.53  0.69        0.13
# LassoLarsCV                                  0.48       0.53  0.69        0.07
# SGDRegressor                                 0.48       0.52  0.69        0.03
# KNeighborsRegressor                          0.46       0.50  0.70        0.03
# AdaBoostRegressor                            0.45       0.50  0.70        0.19
# HuberRegressor                               0.44       0.49  0.71        0.03
# OrthogonalMatchingPursuitCV                  0.44       0.49  0.71        0.02
# LinearSVR                                    0.41       0.46  0.73        0.05
# TweedieRegressor                             0.39       0.44  0.75        0.08
# GaussianProcessRegressor                     0.27       0.33  0.81        0.08
# DecisionTreeRegressor                        0.23       0.29  0.82        0.05
# RANSACRegressor                              0.14       0.22  0.88        0.19
# OrthogonalMatchingPursuit                    0.12       0.19  0.89        0.01
# ExtraTreeRegressor                           0.11       0.19  0.88        0.02
# LassoLars                                   -0.10      -0.01  1.00        0.02
# ElasticNet                                  -0.10      -0.01  1.00        0.02
# Lasso                                       -0.10      -0.01  1.00        0.02
# DummyRegressor                              -0.10      -0.01  1.00        0.03
# PassiveAggressiveRegressor                  -0.26      -0.16  1.03        0.01
# Calculate: Max Strain
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# MLPRegressor                                 0.66       0.69  0.56        0.84
# NuSVR                                        0.62       0.65  0.59        0.11
# SVR                                          0.62       0.65  0.59        0.11
# HistGradientBoostingRegressor                0.61       0.64  0.60        0.89
# LGBMRegressor                                0.61       0.64  0.59        0.19
# ExtraTreesRegressor                          0.57       0.61  0.62        0.50
# XGBRegressor                                 0.56       0.60  0.63        0.53
# RandomForestRegressor                        0.55       0.59  0.64        0.92
# GradientBoostingRegressor                    0.52       0.56  0.66        0.60
# BaggingRegressor                             0.48       0.52  0.69        0.11
# SGDRegressor                                 0.43       0.48  0.72        0.03
# LassoLarsIC                                  0.43       0.48  0.72        0.03
# ElasticNetCV                                 0.43       0.48  0.72        0.16
# LarsCV                                       0.43       0.48  0.72        0.06
# Lars                                         0.43       0.48  0.72        0.03
# LassoCV                                      0.43       0.48  0.72        0.14
# LassoLarsCV                                  0.43       0.48  0.72        0.07
# BayesianRidge                                0.43       0.48  0.72        0.02
# RidgeCV                                      0.43       0.48  0.72        0.03
# KernelRidge                                  0.43       0.48  0.72        0.04
# Ridge                                        0.43       0.48  0.72        0.01
# TransformedTargetRegressor                   0.43       0.48  0.72        0.02
# LinearRegression                             0.43       0.48  0.72        0.02
# HuberRegressor                               0.41       0.46  0.73        0.03
# LinearSVR                                    0.39       0.44  0.75        0.05
# KNeighborsRegressor                          0.37       0.42  0.76        0.02
# AdaBoostRegressor                            0.37       0.42  0.76        0.20
# TweedieRegressor                             0.35       0.41  0.77        0.07
# OrthogonalMatchingPursuitCV                  0.34       0.40  0.77        0.03
# GaussianProcessRegressor                     0.20       0.26  0.86        0.10
# DecisionTreeRegressor                        0.14       0.21  0.88        0.05
# OrthogonalMatchingPursuit                    0.10       0.18  0.91        0.02
# ExtraTreeRegressor                          -0.04       0.05  0.97        0.03
# ElasticNet                                  -0.10      -0.01  1.00        0.02
# DummyRegressor                              -0.10      -0.01  1.00        0.02
# LassoLars                                   -0.10      -0.01  1.00        0.03
# Lasso                                       -0.10      -0.01  1.00        0.02
# RANSACRegressor                             -0.27      -0.16  1.07        0.20
# PassiveAggressiveRegressor                  -0.32      -0.21  1.08        0.02
# Calculate: G. Average
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# MLPRegressor                                 0.88       0.89  0.33        0.84
# NuSVR                                        0.86       0.87  0.35        0.12
# SVR                                          0.86       0.87  0.36        0.10
# LGBMRegressor                                0.84       0.86  0.37        0.19
# HistGradientBoostingRegressor                0.84       0.86  0.38        0.44
# ExtraTreesRegressor                          0.82       0.84  0.40        0.42
# GradientBoostingRegressor                    0.82       0.84  0.40        0.49
# XGBRegressor                                 0.82       0.83  0.41        0.80
# RandomForestRegressor                        0.80       0.82  0.43        0.95
# BaggingRegressor                             0.76       0.78  0.47        0.10
# RidgeCV                                      0.69       0.71  0.53        0.04
# BayesianRidge                                0.69       0.71  0.53        0.02
# ElasticNetCV                                 0.69       0.71  0.53        0.13
# Ridge                                        0.69       0.71  0.53        0.02
# KernelRidge                                  0.69       0.71  0.53        0.04
# LassoCV                                      0.69       0.71  0.53        0.14
# LassoLarsCV                                  0.69       0.71  0.53        0.07
# AdaBoostRegressor                            0.69       0.71  0.53        0.22
# TransformedTargetRegressor                   0.69       0.71  0.53        0.02
# LinearRegression                             0.69       0.71  0.53        0.02
# Lars                                         0.69       0.71  0.53        0.03
# LassoLarsIC                                  0.69       0.71  0.53        0.03
# LarsCV                                       0.69       0.71  0.53        0.06
# SGDRegressor                                 0.69       0.71  0.53        0.04
# HuberRegressor                               0.68       0.71  0.54        0.03
# LinearSVR                                    0.67       0.70  0.55        0.06
# OrthogonalMatchingPursuitCV                  0.67       0.70  0.55        0.02
# KNeighborsRegressor                          0.59       0.62  0.61        0.02
# TweedieRegressor                             0.56       0.60  0.63        0.18
# DecisionTreeRegressor                        0.56       0.60  0.63        0.05
# ExtraTreeRegressor                           0.50       0.54  0.68        0.02
# RANSACRegressor                              0.41       0.46  0.73        0.19
# PassiveAggressiveRegressor                   0.41       0.46  0.73        0.01
# GaussianProcessRegressor                     0.28       0.34  0.81        0.08
# OrthogonalMatchingPursuit                    0.18       0.25  0.86        0.02
# ElasticNet                                  -0.09      -0.00  1.00        0.02
# DummyRegressor                              -0.10      -0.01  1.00        0.02
# Lasso                                       -0.10      -0.01  1.00        0.02
# LassoLars                                   -0.10      -0.01  1.00        0.02

# %% [markdown]
# # Find Second LazyRegressor

# %% [markdown]
# ### Upload all the data once again and divide it into X (inputs) and Y (outputs, predictions)
#
# * Because our data was corrupted during the previous experiment

# %%
######### TODO: Refactor
# Load all data with pandas
data = pd.read_csv('/content/Tunneling_Induced_building_damage_dataset_V2.txt', sep='\t')
data = data.drop(labels = 'Number', axis=1)

data = data.drop(labels = [
    'Identifier',
    'Unnamed: 17',
    'Unnamed: 19',
    'Unnamed: 21',
    'Unnamed: 22',
    'Unnamed: 27',
    'Unnamed: 27',
    'Unnamed: 28',
    'Unnamed: 29',
    'Unnamed: 30',
    'Unnamed: 31'
], axis=1)

# remove outliers
data = data[(np.abs(stats.zscore(data.select_dtypes(exclude='object'))) < 3).all(axis=1)]
data_columns = data.columns
data.head()
X = data.iloc[:,:15].to_numpy()
if task_name == 'Task1':
    Y = data[['L. Average', 'G. Average']]
elif task_name == 'Task2':
    Y = data[['C. Width', 'Tot. Cracks ', 'Slope', 'Tilt', 'Ang. Dist.', 'Max Strain']]
else:
    Y = data[['C. Width', 'Tot. Cracks ', 'L. Average', 'Slope', 'Tilt', 'Ang. Dist.', 'Max Strain', 'G. Average']]
target_columns = Y.columns
Y = Y.to_numpy()
######### END: Refactor

# %% [markdown]
# ### Brute force a second model for our data using LazyRegressor.
#
# * We use cross-validation
# * We use the best model for
# * We pass data through SGTM
# * We save the obtained results

# %%
results = []

model_1_errors_train = []
model_1_errors_test = []
model_2_errors_train = []
model_2_errors_test = []

kf = KFold(n_splits=5, shuffle=True, random_state=42)

for train_index, test_index in kf.split(X, Y):
    X_train, X_test = X[train_index], X[test_index]
    Y_train, Y_test = Y[train_index], Y[test_index]

    scaler_x = MaxAbsScaler()
    scaler_y = MaxAbsScaler()

    X_train = scaler_x.fit_transform(X_train)
    Y_train = scaler_y.fit_transform(Y_train)

    X_test = scaler_x.transform(X_test)
    Y_test = scaler_y.transform(Y_test)

    model1 = ModelStrategy(NuSVR())
    model2 = AdapterSGTM(verbose=1)

    X_train = scaler_x.fit_transform(X_train)
    Y_train = scaler_y.fit_transform(Y_train)
    X_test = scaler_x.transform(X_test)

    # Model 1 fit on the model
    Y_train_pred = model1.fit_transform(X_train, Y_train)
    Y_test_pred = model1.transform(X_test)

    # Use decomposition to increase input features by merge X_train & Y_pred
    X_train_new = model2.fit_transform(np.concatenate((X_train, Y_train_pred), axis=1))
    X_test_new = model2.transform(np.concatenate((X_test, Y_test_pred), axis=1))

    for i, (y_train, y_test) in enumerate(zip(Y_train[:].T, Y_test[:].T)):
        print(f'Training: {target_columns[i]}')
        reg = LazyRegressor(verbose=-10,
                            ignore_warnings=True,
                            custom_metric=None,
                            predictions=True,
                            regressors='all')#regressors)
        models,predictions = reg.fit(X_train_new, X_test_new, y_train, y_test)
        results.append(models)

# %% [markdown]
# ### By using the saved results, we calculate the final accuracy for each output (rating of the models from the best to the worst Adjusted R-Squared metric)

# %%
sorted_results = []
for res in results:
  sorted_results.append(res.sort_values(by=['Model']))

sorted_results

final_results = {target : 0 for target in target_columns}

for i, res in enumerate(sorted_results):
    target = target_columns[i % len(target_columns)]
    final_results[target] = final_results[target] + res.to_numpy()

for target, final_res in final_results.items():
    final_res = final_res / 5
    final_results[target] = final_res

for i, target in enumerate(target_columns):
    print(f'Calculate: {target}')
    print(pd.DataFrame(final_results[target],
                 columns = sorted_results[i].columns,
                 index =   sorted_results[i].index
    ).sort_values(by=['Adjusted R-Squared'], ascending=False))
# Out:
# Calculate: C. Width
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# LGBMRegressor                                0.69       0.73  0.11        0.30
# HistGradientBoostingRegressor                0.68       0.72  0.12        0.78
# ExtraTreesRegressor                          0.68       0.72  0.12        0.38
# GradientBoostingRegressor                    0.67       0.71  0.12        0.73
# XGBRegressor                                 0.67       0.71  0.12        0.64
# RandomForestRegressor                        0.66       0.71  0.12        1.02
# AdaBoostRegressor                            0.65       0.70  0.12        0.26
# NuSVR                                        0.65       0.69  0.12        0.30
# BaggingRegressor                             0.65       0.69  0.12        0.12
# KNeighborsRegressor                          0.64       0.68  0.12        0.04
# SGDRegressor                                 0.62       0.66  0.13        0.04
# TweedieRegressor                             0.62       0.66  0.13        0.12
# HuberRegressor                               0.61       0.66  0.13        0.06
# SVR                                          0.61       0.66  0.13        0.07
# OrthogonalMatchingPursuitCV                  0.61       0.66  0.13        0.02
# LinearSVR                                    0.61       0.66  0.13        0.13
# OrthogonalMatchingPursuit                    0.61       0.66  0.13        0.02
# ElasticNetCV                                 0.61       0.66  0.13        0.29
# Ridge                                        0.61       0.66  0.13        0.02
# LassoCV                                      0.61       0.65  0.13        0.25
# BayesianRidge                                0.60       0.65  0.13        0.03
# LassoLarsCV                                  0.60       0.65  0.13        0.10
# RidgeCV                                      0.60       0.65  0.13        0.04
# LassoLarsIC                                  0.60       0.65  0.13        0.04
# TransformedTargetRegressor                   0.60       0.65  0.13        0.02
# LinearRegression                             0.60       0.65  0.13        0.04
# DecisionTreeRegressor                        0.59       0.64  0.13        0.06
# PassiveAggressiveRegressor                   0.54       0.60  0.14        0.02
# ExtraTreeRegressor                           0.53       0.59  0.14        0.04
# MLPRegressor                                 0.47       0.54  0.15        0.21
# PoissonRegressor                             0.46       0.53  0.15        0.17
# KernelRidge                                 -0.03       0.10  0.21        0.05
# RANSACRegressor                             -0.07       0.06  0.21        0.27
# Lasso                                       -0.15      -0.01  0.22        0.03
# DummyRegressor                              -0.15      -0.01  0.22        0.03
# ElasticNet                                  -0.15      -0.01  0.22        0.02
# LassoLars                                   -0.15      -0.01  0.22        0.03
# GaussianProcessRegressor                    -0.39      -0.21  0.24        0.12
# LarsCV                                      -5.38      -4.58  0.38        0.08
# Lars                                        -6.21      -5.30  0.44        0.04
# Calculate: Tot. Cracks
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                          0.73       0.77  0.10        0.42
# HistGradientBoostingRegressor                0.73       0.76  0.11        0.77
# LGBMRegressor                                0.72       0.76  0.11        0.30
# NuSVR                                        0.72       0.76  0.11        0.33
# GradientBoostingRegressor                    0.72       0.76  0.11        1.14
# XGBRegressor                                 0.72       0.75  0.11        0.38
# RandomForestRegressor                        0.71       0.75  0.11        0.83
# BaggingRegressor                             0.71       0.75  0.11        0.13
# KNeighborsRegressor                          0.70       0.74  0.11        0.09
# SGDRegressor                                 0.70       0.74  0.11        0.03
# HuberRegressor                               0.69       0.73  0.11        0.06
# LinearSVR                                    0.69       0.73  0.11        0.13
# LarsCV                                       0.69       0.73  0.11        0.07
# OrthogonalMatchingPursuit                    0.69       0.73  0.11        0.02
# ElasticNetCV                                 0.69       0.73  0.11        0.24
# BayesianRidge                                0.69       0.73  0.11        0.03
# LassoCV                                      0.69       0.73  0.11        0.17
# RidgeCV                                      0.69       0.73  0.11        0.03
# Ridge                                        0.69       0.73  0.11        0.01
# AdaBoostRegressor                            0.69       0.73  0.11        0.25
# LassoLarsCV                                  0.69       0.73  0.11        0.10
# LassoLarsIC                                  0.69       0.72  0.11        0.04
# LinearRegression                             0.68       0.72  0.11        0.03
# TransformedTargetRegressor                   0.68       0.72  0.11        0.02
# OrthogonalMatchingPursuitCV                  0.68       0.72  0.11        0.02
# SVR                                          0.68       0.72  0.11        0.08
# TweedieRegressor                             0.66       0.71  0.12        0.12
# Lars                                         0.66       0.71  0.12        0.03
# DecisionTreeRegressor                        0.64       0.68  0.12        0.06
# ExtraTreeRegressor                           0.59       0.64  0.13        0.04
# PassiveAggressiveRegressor                   0.57       0.62  0.13        0.02
# MLPRegressor                                 0.52       0.58  0.14        0.27
# PoissonRegressor                             0.49       0.56  0.14        0.15
# RANSACRegressor                              0.33       0.41  0.16        0.27
# KernelRidge                                  0.16       0.26  0.19        0.04
# Lasso                                       -0.15      -0.01  0.22        0.03
# DummyRegressor                              -0.15      -0.01  0.22        0.03
# ElasticNet                                  -0.15      -0.01  0.22        0.03
# LassoLars                                   -0.15      -0.01  0.22        0.03
# GaussianProcessRegressor                    -0.30      -0.14  0.23        0.16
# Calculate: L. Average
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# HistGradientBoostingRegressor                0.78       0.81  0.10        0.50
# LGBMRegressor                                0.78       0.81  0.10        0.38
# ExtraTreesRegressor                          0.78       0.81  0.11        0.37
# RandomForestRegressor                        0.78       0.80  0.11        1.00
# GradientBoostingRegressor                    0.77       0.80  0.11        0.71
# NuSVR                                        0.77       0.80  0.11        0.32
# XGBRegressor                                 0.77       0.80  0.11        1.15
# BaggingRegressor                             0.76       0.79  0.11        0.11
# KNeighborsRegressor                          0.76       0.79  0.11        0.08
# DecisionTreeRegressor                        0.75       0.78  0.11        0.06
# AdaBoostRegressor                            0.75       0.78  0.11        0.26
# LarsCV                                       0.75       0.78  0.11        0.07
# SGDRegressor                                 0.75       0.78  0.11        0.03
# OrthogonalMatchingPursuit                    0.75       0.78  0.11        0.02
# HuberRegressor                               0.74       0.78  0.11        0.07
# OrthogonalMatchingPursuitCV                  0.74       0.78  0.11        0.03
# ElasticNetCV                                 0.74       0.78  0.11        0.37
# LinearSVR                                    0.74       0.78  0.11        0.13
# LassoCV                                      0.74       0.78  0.11        0.22
# Ridge                                        0.74       0.78  0.11        0.02
# BayesianRidge                                0.74       0.78  0.11        0.02
# LassoLarsCV                                  0.74       0.77  0.11        0.09
# RidgeCV                                      0.74       0.77  0.11        0.03
# LassoLarsIC                                  0.74       0.77  0.11        0.03
# LinearRegression                             0.74       0.77  0.11        0.03
# TransformedTargetRegressor                   0.74       0.77  0.11        0.02
# TweedieRegressor                             0.74       0.77  0.11        0.10
# SVR                                          0.73       0.77  0.12        0.09
# PassiveAggressiveRegressor                   0.71       0.74  0.12        0.02
# ExtraTreeRegressor                           0.70       0.74  0.12        0.04
# MLPRegressor                                 0.60       0.65  0.14        0.23
# PoissonRegressor                             0.59       0.64  0.14        0.21
# KernelRidge                                  0.06       0.17  0.22        0.05
# LassoLars                                   -0.15      -0.01  0.24        0.03
# DummyRegressor                              -0.15      -0.01  0.24        0.03
# ElasticNet                                  -0.15      -0.01  0.24        0.02
# Lasso                                       -0.15      -0.01  0.24        0.03
# GaussianProcessRegressor                    -0.40      -0.23  0.27        0.12
# RANSACRegressor                             -0.63      -0.43  0.26        0.30
# Lars                                        -7.60      -6.51  0.38        0.04
# Calculate: Slope
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# NuSVR                                        0.88       0.90  0.08        0.31
# ExtraTreesRegressor                          0.88       0.89  0.08        0.64
# SGDRegressor                                 0.88       0.89  0.08        0.02
# RandomForestRegressor                        0.88       0.89  0.08        1.14
# XGBRegressor                                 0.87       0.89  0.08        0.66
# HistGradientBoostingRegressor                0.87       0.89  0.08        0.53
# BaggingRegressor                             0.87       0.89  0.08        0.19
# LGBMRegressor                                0.87       0.89  0.08        0.26
# OrthogonalMatchingPursuit                    0.87       0.89  0.08        0.02
# HuberRegressor                               0.87       0.89  0.08        0.07
# LinearSVR                                    0.87       0.89  0.08        0.13
# GradientBoostingRegressor                    0.87       0.89  0.08        0.75
# ElasticNetCV                                 0.87       0.89  0.08        0.38
# LassoCV                                      0.87       0.89  0.08        0.22
# Ridge                                        0.87       0.89  0.08        0.02
# OrthogonalMatchingPursuitCV                  0.87       0.89  0.08        0.02
# LassoLarsCV                                  0.87       0.89  0.08        0.09
# LarsCV                                       0.87       0.89  0.08        0.08
# BayesianRidge                                0.87       0.89  0.08        0.06
# RidgeCV                                      0.87       0.89  0.08        0.02
# LassoLarsIC                                  0.87       0.89  0.08        0.03
# TransformedTargetRegressor                   0.87       0.89  0.08        0.03
# LinearRegression                             0.87       0.89  0.08        0.03
# RANSACRegressor                              0.87       0.89  0.08        0.03
# DecisionTreeRegressor                        0.87       0.88  0.08        0.09
# AdaBoostRegressor                            0.86       0.88  0.09        0.30
# ExtraTreeRegressor                           0.85       0.87  0.09        0.04
# PassiveAggressiveRegressor                   0.83       0.86  0.09        0.02
# SVR                                          0.83       0.85  0.10        0.05
# TweedieRegressor                             0.83       0.85  0.10        0.14
# KNeighborsRegressor                          0.82       0.84  0.10        0.04
# GammaRegressor                               0.78       0.81  0.11        0.18
# MLPRegressor                                 0.75       0.79  0.12        0.19
# PoissonRegressor                             0.72       0.75  0.12        0.16
# DummyRegressor                              -0.16      -0.01  0.25        0.04
# LassoLars                                   -0.16      -0.01  0.25        0.03
# Lasso                                       -0.16      -0.01  0.25        0.02
# ElasticNet                                  -0.16      -0.01  0.25        0.03
# KernelRidge                                 -1.00      -0.74  0.33        0.05
# GaussianProcessRegressor                    -1.25      -0.96  0.35        0.16
# Lars                                       -27.33     -23.75  0.61        0.04
# Calculate: Tilt
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# NuSVR                                        0.88       0.89  0.08        0.49
# ExtraTreesRegressor                          0.87       0.89  0.08        0.54
# LGBMRegressor                                0.87       0.89  0.08        0.26
# HistGradientBoostingRegressor                0.87       0.89  0.08        0.88
# RandomForestRegressor                        0.87       0.89  0.08        1.59
# XGBRegressor                                 0.87       0.89  0.08        0.82
# SGDRegressor                                 0.87       0.88  0.08        0.03
# LinearSVR                                    0.87       0.88  0.08        0.14
# BaggingRegressor                             0.87       0.88  0.08        0.13
# GradientBoostingRegressor                    0.87       0.88  0.08        0.69
# HuberRegressor                               0.87       0.88  0.08        0.07
# OrthogonalMatchingPursuit                    0.87       0.88  0.08        0.03
# OrthogonalMatchingPursuitCV                  0.87       0.88  0.08        0.05
# DecisionTreeRegressor                        0.87       0.88  0.08        0.05
# RANSACRegressor                              0.86       0.88  0.08        0.08
# ElasticNetCV                                 0.86       0.88  0.08        0.25
# LassoCV                                      0.86       0.88  0.08        0.23
# Ridge                                        0.86       0.88  0.08        0.02
# LassoLarsCV                                  0.86       0.88  0.08        0.10
# BayesianRidge                                0.86       0.88  0.08        0.02
# RidgeCV                                      0.86       0.88  0.08        0.03
# LassoLarsIC                                  0.86       0.88  0.08        0.04
# TransformedTargetRegressor                   0.86       0.88  0.08        0.02
# LinearRegression                             0.86       0.88  0.08        0.04
# LarsCV                                       0.86       0.87  0.09        0.08
# AdaBoostRegressor                            0.85       0.87  0.09        0.24
# ExtraTreeRegressor                           0.85       0.87  0.09        0.05
# Lars                                         0.84       0.86  0.09        0.04
# SVR                                          0.82       0.84  0.10        0.04
# PassiveAggressiveRegressor                   0.82       0.84  0.10        0.03
# TweedieRegressor                             0.82       0.84  0.10        0.11
# KNeighborsRegressor                          0.81       0.84  0.10        0.08
# GammaRegressor                               0.77       0.80  0.11        0.15
# MLPRegressor                                 0.75       0.78  0.12        0.30
# PoissonRegressor                             0.70       0.74  0.13        0.25
# ElasticNet                                  -0.16      -0.01  0.25        0.02
# DummyRegressor                              -0.16      -0.01  0.25        0.02
# LassoLars                                   -0.16      -0.01  0.25        0.03
# Lasso                                       -0.16      -0.01  0.25        0.03
# KernelRidge                                 -1.01      -0.76  0.33        0.05
# GaussianProcessRegressor                    -1.25      -0.96  0.35        0.14
# Calculate: Ang. Dist.
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# NuSVR                                        0.76       0.79  0.08        0.47
# GradientBoostingRegressor                    0.75       0.79  0.08        0.75
# ExtraTreesRegressor                          0.75       0.79  0.08        0.52
# RandomForestRegressor                        0.75       0.78  0.08        1.24
# LGBMRegressor                                0.75       0.78  0.08        0.31
# BaggingRegressor                             0.75       0.78  0.08        0.13
# HistGradientBoostingRegressor                0.74       0.78  0.08        0.52
# XGBRegressor                                 0.74       0.78  0.08        0.61
# SGDRegressor                                 0.73       0.77  0.09        0.03
# HuberRegressor                               0.73       0.76  0.09        0.07
# OrthogonalMatchingPursuit                    0.73       0.76  0.09        0.02
# RANSACRegressor                              0.73       0.76  0.09        0.21
# OrthogonalMatchingPursuitCV                  0.73       0.76  0.09        0.03
# LinearSVR                                    0.73       0.76  0.09        0.14
# LarsCV                                       0.72       0.76  0.09        0.08
# LassoLarsCV                                  0.72       0.76  0.09        0.09
# LassoCV                                      0.72       0.76  0.09        0.18
# ElasticNetCV                                 0.72       0.76  0.09        0.16
# Ridge                                        0.72       0.75  0.09        0.02
# AdaBoostRegressor                            0.72       0.75  0.09        0.23
# KNeighborsRegressor                          0.72       0.75  0.09        0.09
# BayesianRidge                                0.72       0.75  0.09        0.03
# RidgeCV                                      0.72       0.75  0.09        0.03
# LassoLarsIC                                  0.72       0.75  0.09        0.04
# TransformedTargetRegressor                   0.72       0.75  0.09        0.03
# LinearRegression                             0.72       0.75  0.09        0.04
# DecisionTreeRegressor                        0.72       0.75  0.09        0.07
# ExtraTreeRegressor                           0.71       0.75  0.09        0.04
# Lars                                         0.69       0.73  0.09        0.03
# TweedieRegressor                             0.68       0.72  0.09        0.12
# SVR                                          0.67       0.71  0.10        0.06
# PassiveAggressiveRegressor                   0.64       0.69  0.10        0.02
# GammaRegressor                               0.57       0.62  0.11        0.19
# PoissonRegressor                             0.51       0.58  0.12        0.13
# MLPRegressor                                 0.50       0.56  0.12        0.25
# KernelRidge                                  0.09       0.21  0.16        0.06
# DummyRegressor                              -0.15      -0.01  0.18        0.03
# LassoLars                                   -0.15      -0.01  0.18        0.02
# Lasso                                       -0.15      -0.01  0.18        0.03
# ElasticNet                                  -0.15      -0.01  0.18        0.02
# GaussianProcessRegressor                    -0.40      -0.23  0.20        0.16
# Calculate: Max Strain
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# LGBMRegressor                                0.68       0.72  0.11        0.27
# HistGradientBoostingRegressor                0.68       0.72  0.11        1.45
# GradientBoostingRegressor                    0.67       0.71  0.11        1.11
# ExtraTreesRegressor                          0.67       0.71  0.11        0.67
# NuSVR                                        0.66       0.70  0.11        0.35
# RandomForestRegressor                        0.66       0.70  0.11        1.36
# XGBRegressor                                 0.66       0.70  0.11        0.99
# BaggingRegressor                             0.66       0.70  0.11        0.16
# AdaBoostRegressor                            0.65       0.69  0.12        0.25
# KNeighborsRegressor                          0.64       0.68  0.12        0.07
# TweedieRegressor                             0.62       0.66  0.12        0.09
# OrthogonalMatchingPursuitCV                  0.62       0.66  0.12        0.03
# OrthogonalMatchingPursuit                    0.61       0.66  0.12        0.02
# SGDRegressor                                 0.61       0.66  0.12        0.03
# LinearSVR                                    0.61       0.66  0.12        0.13
# HuberRegressor                               0.61       0.66  0.12        0.08
# Ridge                                        0.60       0.65  0.12        0.02
# ElasticNetCV                                 0.60       0.65  0.12        0.34
# SVR                                          0.60       0.65  0.12        0.07
# LassoCV                                      0.60       0.65  0.12        0.28
# BayesianRidge                                0.60       0.65  0.12        0.03
# LassoLarsIC                                  0.60       0.65  0.12        0.04
# LassoLarsCV                                  0.60       0.65  0.12        0.09
# RidgeCV                                      0.60       0.65  0.12        0.03
# LinearRegression                             0.60       0.65  0.12        0.03
# TransformedTargetRegressor                   0.60       0.65  0.12        0.02
# RANSACRegressor                              0.58       0.63  0.13        0.29
# ExtraTreeRegressor                           0.58       0.63  0.13        0.04
# DecisionTreeRegressor                        0.57       0.62  0.13        0.07
# PassiveAggressiveRegressor                   0.52       0.58  0.14        0.02
# PoissonRegressor                             0.46       0.53  0.14        0.14
# MLPRegressor                                 0.45       0.52  0.14        0.26
# KernelRidge                                 -0.09       0.05  0.20        0.06
# ElasticNet                                  -0.15      -0.01  0.21        0.02
# DummyRegressor                              -0.15      -0.01  0.21        0.02
# LassoLars                                   -0.15      -0.01  0.21        0.03
# Lasso                                       -0.15      -0.01  0.21        0.03
# GaussianProcessRegressor                    -0.43      -0.25  0.23        0.21
# GammaRegressor                              -1.44      -1.14  0.28        0.18
# LarsCV                                      -1.61      -1.28  0.23        0.09
# Lars                                    -61818.79  -54006.40 20.27        0.05
# Calculate: G. Average
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# GradientBoostingRegressor                    0.87       0.89  0.08        0.80
# NuSVR                                        0.87       0.89  0.08        0.33
# ExtraTreesRegressor                          0.87       0.89  0.08        0.55
# LGBMRegressor                                0.87       0.89  0.08        0.33
# RandomForestRegressor                        0.87       0.89  0.08        1.23
# HistGradientBoostingRegressor                0.87       0.89  0.08        0.76
# XGBRegressor                                 0.87       0.88  0.08        0.66
# BaggingRegressor                             0.87       0.88  0.08        0.12
# SGDRegressor                                 0.86       0.88  0.08        0.04
# HuberRegressor                               0.86       0.88  0.08        0.07
# LassoLarsCV                                  0.86       0.88  0.08        0.08
# LassoCV                                      0.86       0.88  0.08        0.15
# LarsCV                                       0.86       0.88  0.08        0.07
# OrthogonalMatchingPursuit                    0.86       0.88  0.08        0.02
# LinearSVR                                    0.86       0.88  0.08        0.13
# ElasticNetCV                                 0.86       0.88  0.08        0.20
# OrthogonalMatchingPursuitCV                  0.86       0.88  0.08        0.03
# RANSACRegressor                              0.86       0.88  0.08        0.04
# Ridge                                        0.86       0.88  0.08        0.02
# LassoLarsIC                                  0.86       0.88  0.08        0.04
# BayesianRidge                                0.86       0.88  0.08        0.02
# Lars                                         0.86       0.88  0.08        0.03
# RidgeCV                                      0.86       0.88  0.08        0.03
# TransformedTargetRegressor                   0.86       0.88  0.08        0.03
# LinearRegression                             0.86       0.88  0.08        0.03
# AdaBoostRegressor                            0.86       0.87  0.08        0.23
# DecisionTreeRegressor                        0.85       0.87  0.08        0.06
# ExtraTreeRegressor                           0.84       0.86  0.09        0.03
# TweedieRegressor                             0.84       0.86  0.09        0.14
# KNeighborsRegressor                          0.84       0.86  0.09        0.08
# SVR                                          0.82       0.84  0.09        0.04
# PassiveAggressiveRegressor                   0.82       0.84  0.09        0.02
# GammaRegressor                               0.75       0.78  0.11        0.18
# PoissonRegressor                             0.73       0.76  0.11        0.17
# MLPRegressor                                 0.71       0.75  0.11        0.20
# DummyRegressor                              -0.15      -0.01  0.23        0.02
# ElasticNet                                  -0.15      -0.01  0.23        0.02
# LassoLars                                   -0.15      -0.01  0.23        0.03
# Lasso                                       -0.15      -0.01  0.23        0.02
# KernelRidge                                 -0.79      -0.56  0.29        0.05
# GaussianProcessRegressor                    -1.08      -0.82  0.31        0.18

# %%
for i, target in enumerate(target_columns):
    print(f'Calculate: {target}')
    print(pd.DataFrame(final_results[target],
                 columns = sorted_results[i].columns,
                 index =   sorted_results[i].index
    ).sort_values(by=['Adjusted R-Squared'], ascending=False).iloc[:1])
# Out:
# Calculate: C. Width
#                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# LGBMRegressor                0.69       0.73  0.11        0.30
# Calculate: Tot. Cracks
#                      Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                0.73       0.77  0.10        0.42
# Calculate: L. Average
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# HistGradientBoostingRegressor                0.78       0.81  0.10        0.50
# Calculate: Slope
#        Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# NuSVR                0.88       0.90  0.08        0.31
# Calculate: Tilt
#        Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# NuSVR                0.88       0.89  0.08        0.49
# Calculate: Ang. Dist.
#        Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# NuSVR                0.76       0.79  0.08        0.47
# Calculate: Max Strain
#                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# LGBMRegressor                0.68       0.72  0.11        0.27
# Calculate: G. Average
#                            Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# GradientBoostingRegressor                0.87       0.89  0.08        0.80

# %% [markdown]
# # Find Second LazyRegressor with PolyScaler

# %% [markdown]
# Do everything same, but here the polynomial scaling will be used for the second model inputs

# %%
######### TODO: Refactor
# Load all data with pandas
data = pd.read_csv('/content/Tunneling_Induced_building_damage_dataset_V2.txt', sep='\t')
data = data.drop(labels = 'Number', axis=1)

data = data.drop(labels = [
    'Identifier',
    'Unnamed: 17',
    'Unnamed: 19',
    'Unnamed: 21',
    'Unnamed: 22',
    'Unnamed: 27',
    'Unnamed: 27',
    'Unnamed: 28',
    'Unnamed: 29',
    'Unnamed: 30',
    'Unnamed: 31'
], axis=1)

# remove outliers
data = data[(np.abs(stats.zscore(data.select_dtypes(exclude='object'))) < 3).all(axis=1)]
data_columns = data.columns
data.head()
X = data.iloc[:,:15].to_numpy()
if task_name == 'Task1':
    Y = data[['L. Average', 'G. Average']]
elif task_name == 'Task2':
    Y = data[['C. Width', 'Tot. Cracks ', 'Slope', 'Tilt', 'Ang. Dist.', 'Max Strain']]
else:
    Y = data[['C. Width', 'Tot. Cracks ', 'L. Average', 'Slope', 'Tilt', 'Ang. Dist.', 'Max Strain', 'G. Average']]
target_columns = Y.columns
Y = Y.to_numpy()
######### END: Refactor

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
results = []

model_1_errors_train = []
model_1_errors_test = []
model_2_errors_train = []
model_2_errors_test = []

kf = KFold(n_splits=5, shuffle=True, random_state=42)

for train_index, test_index in kf.split(X, Y):
    X_train, X_test = X[train_index], X[test_index]
    Y_train, Y_test = Y[train_index], Y[test_index]

    scaler_x = MaxAbsScaler()
    scaler_y = MaxAbsScaler()

    X_train = scaler_x.fit_transform(X_train)
    Y_train = scaler_y.fit_transform(Y_train)

    X_test = scaler_x.transform(X_test)
    Y_test = scaler_y.transform(Y_test)

    model1 = ModelStrategy(NuSVR())
    model2 = AdapterSGTM(verbose=1)

    X_train = scaler_x.fit_transform(X_train)
    Y_train = scaler_y.fit_transform(Y_train)
    X_test = scaler_x.transform(X_test)

    # Model 1 fit on the model
    Y_train_pred = model1.fit_transform(X_train, Y_train)
    Y_test_pred = model1.transform(X_test)

    # Use decomposition to increase input features by merge X_train & Y_pred
    X_train_new = model2.fit_transform(np.concatenate((X_train, Y_train_pred), axis=1))
    X_test_new = model2.transform(np.concatenate((X_test, Y_test_pred), axis=1))

    poly = PolynomialFeatures(2)
    X_train_poly = poly.fit_transform(X_train_new[:,:3])
    X_test_poly = poly.transform(X_test_new[:,:3])

    X_train_new = np.concatenate((X_train_poly, X_train_new), axis=1)
    X_test_new =  np.concatenate((X_test_poly, X_test_new), axis=1)

    for i, (y_train, y_test) in enumerate(zip(Y_train[:].T, Y_test[:].T)):
        print(f'Training: {target_columns[i]}')
        reg = LazyRegressor(verbose=-10,
                            ignore_warnings=True,
                            custom_metric=None,
                            predictions=True,
                            regressors='all')#regressors)
        models,predictions = reg.fit(X_train_new, X_test_new, y_train, y_test)
        results.append(models)

# %%
sorted_results = []
for res in results:
  sorted_results.append(res.sort_values(by=['Model']))

sorted_results

final_results = {target : 0 for target in target_columns}

for i, res in enumerate(sorted_results):
    target = target_columns[i % len(target_columns)]
    final_results[target] = final_results[target] + res.to_numpy()

for target, final_res in final_results.items():
    final_res = final_res / 5
    final_results[target] = final_res

for i, target in enumerate(target_columns):
    print(f'Calculate: {target}')
    print(pd.DataFrame(final_results[target],
                 columns = sorted_results[i].columns,
                 index =   sorted_results[i].index
    ).sort_values(by=['Adjusted R-Squared'], ascending=False))
# Out:
# Calculate: C. Width
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# LGBMRegressor                                0.66       0.72  0.12        0.43
# HistGradientBoostingRegressor                0.66       0.72  0.12        0.98
# ExtraTreesRegressor                          0.66       0.72  0.12        0.41
# XGBRegressor                                 0.65       0.71  0.12        0.52
# GradientBoostingRegressor                    0.65       0.71  0.12        1.05
# RandomForestRegressor                        0.64       0.71  0.12        1.11
# AdaBoostRegressor                            0.63       0.70  0.12        0.27
# BaggingRegressor                             0.63       0.69  0.12        0.13
# NuSVR                                        0.61       0.68  0.12        0.29
# LarsCV                                       0.59       0.67  0.13        0.09
# TweedieRegressor                             0.59       0.66  0.13        0.09
# SGDRegressor                                 0.59       0.66  0.13        0.03
# LinearSVR                                    0.59       0.66  0.13        0.14
# HuberRegressor                               0.59       0.66  0.13        0.07
# OrthogonalMatchingPursuitCV                  0.59       0.66  0.13        0.02
# OrthogonalMatchingPursuit                    0.58       0.66  0.13        0.02
# BayesianRidge                                0.58       0.66  0.13        0.04
# Ridge                                        0.58       0.66  0.13        0.01
# ElasticNetCV                                 0.58       0.66  0.13        0.24
# LassoCV                                      0.58       0.66  0.13        0.25
# KNeighborsRegressor                          0.58       0.65  0.13        0.02
# SVR                                          0.58       0.65  0.13        0.06
# LassoLarsCV                                  0.58       0.65  0.13        0.09
# LassoLarsIC                                  0.58       0.65  0.13        0.05
# RidgeCV                                      0.58       0.65  0.13        0.03
# TransformedTargetRegressor                   0.57       0.65  0.13        0.02
# LinearRegression                             0.57       0.65  0.13        0.03
# PassiveAggressiveRegressor                   0.53       0.62  0.13        0.02
# DecisionTreeRegressor                        0.52       0.61  0.14        0.08
# ExtraTreeRegressor                           0.47       0.57  0.15        0.03
# PoissonRegressor                             0.42       0.53  0.15        0.18
# MLPRegressor                                 0.41       0.52  0.15        0.26
# KernelRidge                                 -0.09       0.10  0.21        0.04
# LassoLars                                   -0.23      -0.01  0.22        0.03
# Lasso                                       -0.23      -0.01  0.22        0.03
# DummyRegressor                              -0.23      -0.01  0.22        0.03
# ElasticNet                                  -0.23      -0.01  0.22        0.02
# GaussianProcessRegressor                    -0.70      -0.39  0.26        0.09
# Lars                                     -4085.19   -3348.34  5.87        0.04
# Calculate: Tot. Cracks
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# HistGradientBoostingRegressor                0.71       0.76  0.11        0.59
# ExtraTreesRegressor                          0.71       0.76  0.11        0.45
# LGBMRegressor                                0.71       0.76  0.11        0.36
# GradientBoostingRegressor                    0.70       0.76  0.11        1.06
# XGBRegressor                                 0.70       0.75  0.11        0.97
# RandomForestRegressor                        0.69       0.75  0.11        1.05
# NuSVR                                        0.69       0.74  0.11        0.29
# BaggingRegressor                             0.69       0.74  0.11        0.14
# SGDRegressor                                 0.68       0.74  0.11        0.04
# AdaBoostRegressor                            0.68       0.74  0.11        0.32
# HuberRegressor                               0.67       0.73  0.11        0.07
# LarsCV                                       0.67       0.73  0.11        0.08
# LinearSVR                                    0.67       0.73  0.11        0.15
# BayesianRidge                                0.67       0.73  0.11        0.03
# ElasticNetCV                                 0.67       0.73  0.11        0.27
# LassoCV                                      0.67       0.73  0.11        0.20
# LassoLarsIC                                  0.66       0.73  0.11        0.04
# Ridge                                        0.66       0.73  0.11        0.02
# RidgeCV                                      0.66       0.73  0.11        0.04
# TransformedTargetRegressor                   0.66       0.72  0.11        0.02
# LinearRegression                             0.66       0.72  0.11        0.03
# OrthogonalMatchingPursuit                    0.66       0.72  0.11        0.02
# OrthogonalMatchingPursuitCV                  0.66       0.72  0.11        0.03
# KNeighborsRegressor                          0.66       0.72  0.12        0.06
# LassoLarsCV                                  0.65       0.72  0.12        0.09
# SVR                                          0.64       0.71  0.12        0.07
# TweedieRegressor                             0.64       0.71  0.12        0.14
# ExtraTreeRegressor                           0.61       0.68  0.12        0.04
# DecisionTreeRegressor                        0.60       0.67  0.12        0.07
# PassiveAggressiveRegressor                   0.56       0.64  0.13        0.02
# PoissonRegressor                             0.46       0.56  0.14        0.16
# MLPRegressor                                 0.43       0.53  0.15        0.26
# Lars                                         0.43       0.53  0.14        0.04
# KernelRidge                                  0.10       0.26  0.19        0.05
# DummyRegressor                              -0.23      -0.01  0.22        0.03
# LassoLars                                   -0.23      -0.01  0.22        0.03
# ElasticNet                                  -0.23      -0.01  0.22        0.02
# Lasso                                       -0.23      -0.01  0.22        0.03
# GaussianProcessRegressor                    -0.61      -0.32  0.25        0.12
# Calculate: L. Average
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# HistGradientBoostingRegressor                0.77       0.81  0.10        0.60
# ExtraTreesRegressor                          0.77       0.81  0.10        0.40
# LGBMRegressor                                0.76       0.81  0.11        0.38
# RandomForestRegressor                        0.76       0.80  0.11        1.28
# GradientBoostingRegressor                    0.76       0.80  0.11        0.90
# XGBRegressor                                 0.75       0.80  0.11        0.93
# BaggingRegressor                             0.75       0.79  0.11        0.12
# NuSVR                                        0.74       0.79  0.11        0.30
# AdaBoostRegressor                            0.73       0.78  0.11        0.28
# LarsCV                                       0.73       0.78  0.11        0.08
# OrthogonalMatchingPursuit                    0.73       0.78  0.11        0.02
# SGDRegressor                                 0.73       0.78  0.11        0.05
# HuberRegressor                               0.73       0.78  0.11        0.07
# DecisionTreeRegressor                        0.73       0.78  0.11        0.06
# OrthogonalMatchingPursuitCV                  0.73       0.78  0.11        0.02
# ElasticNetCV                                 0.73       0.78  0.11        0.21
# LassoCV                                      0.73       0.78  0.11        0.20
# BayesianRidge                                0.73       0.78  0.11        0.03
# Ridge                                        0.73       0.78  0.11        0.02
# LassoLarsCV                                  0.73       0.78  0.11        0.09
# LassoLarsIC                                  0.73       0.77  0.11        0.04
# RidgeCV                                      0.72       0.77  0.11        0.05
# TransformedTargetRegressor                   0.72       0.77  0.11        0.02
# LinearRegression                             0.72       0.77  0.11        0.03
# LinearSVR                                    0.72       0.77  0.11        0.15
# TweedieRegressor                             0.72       0.77  0.11        0.16
# KNeighborsRegressor                          0.72       0.77  0.12        0.10
# SVR                                          0.71       0.76  0.12        0.06
# Lars                                         0.70       0.76  0.12        0.04
# PassiveAggressiveRegressor                   0.69       0.74  0.12        0.02
# ExtraTreeRegressor                           0.68       0.74  0.12        0.04
# PoissonRegressor                             0.56       0.64  0.14        0.14
# MLPRegressor                                 0.55       0.63  0.15        0.25
# KernelRidge                                 -0.01       0.18  0.22        0.05
# LassoLars                                   -0.23      -0.01  0.24        0.03
# DummyRegressor                              -0.23      -0.01  0.24        0.03
# Lasso                                       -0.23      -0.01  0.24        0.02
# ElasticNet                                  -0.23      -0.01  0.24        0.02
# GaussianProcessRegressor                    -0.74      -0.43  0.29        0.08
# Calculate: Slope
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# NuSVR                                        0.87       0.89  0.08        0.33
# ExtraTreesRegressor                          0.87       0.89  0.08        0.62
# SGDRegressor                                 0.87       0.89  0.08        0.03
# RandomForestRegressor                        0.87       0.89  0.08        1.45
# HistGradientBoostingRegressor                0.87       0.89  0.08        1.22
# XGBRegressor                                 0.87       0.89  0.08        0.93
# LGBMRegressor                                0.87       0.89  0.08        0.39
# BaggingRegressor                             0.86       0.89  0.08        0.15
# HuberRegressor                               0.86       0.89  0.08        0.08
# ElasticNetCV                                 0.86       0.89  0.08        0.21
# LarsCV                                       0.86       0.89  0.08        0.08
# LassoCV                                      0.86       0.89  0.08        0.22
# OrthogonalMatchingPursuit                    0.86       0.89  0.08        0.02
# LassoLarsCV                                  0.86       0.89  0.08        0.10
# Ridge                                        0.86       0.89  0.08        0.02
# LassoLarsIC                                  0.86       0.89  0.08        0.04
# OrthogonalMatchingPursuitCV                  0.86       0.89  0.08        0.02
# RANSACRegressor                              0.86       0.89  0.08        0.06
# BayesianRidge                                0.86       0.89  0.08        0.03
# GradientBoostingRegressor                    0.86       0.89  0.08        0.93
# RidgeCV                                      0.86       0.89  0.08        0.02
# LinearSVR                                    0.86       0.89  0.08        0.15
# TransformedTargetRegressor                   0.86       0.89  0.08        0.03
# LinearRegression                             0.86       0.89  0.08        0.04
# ExtraTreeRegressor                           0.86       0.88  0.09        0.05
# DecisionTreeRegressor                        0.85       0.88  0.09        0.08
# AdaBoostRegressor                            0.85       0.88  0.09        0.29
# PassiveAggressiveRegressor                   0.82       0.85  0.09        0.02
# SVR                                          0.82       0.85  0.10        0.05
# TweedieRegressor                             0.82       0.85  0.10        0.09
# Lars                                         0.80       0.84  0.10        0.04
# KNeighborsRegressor                          0.78       0.82  0.11        0.04
# GammaRegressor                               0.77       0.81  0.11        0.14
# PoissonRegressor                             0.70       0.75  0.12        0.16
# MLPRegressor                                 0.66       0.72  0.13        0.25
# DummyRegressor                              -0.23      -0.01  0.25        0.02
# LassoLars                                   -0.23      -0.01  0.25        0.03
# ElasticNet                                  -0.23      -0.01  0.25        0.01
# Lasso                                       -0.23      -0.01  0.25        0.02
# KernelRidge                                 -1.13      -0.74  0.33        0.05
# GaussianProcessRegressor                    -1.85      -1.33  0.38        0.11
# Calculate: Tilt
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                          0.86       0.89  0.08        0.68
# RandomForestRegressor                        0.86       0.89  0.08        1.59
# LGBMRegressor                                0.86       0.89  0.08        0.34
# HistGradientBoostingRegressor                0.86       0.89  0.08        0.96
# BaggingRegressor                             0.86       0.89  0.08        0.17
# NuSVR                                        0.86       0.89  0.08        0.32
# XGBRegressor                                 0.86       0.89  0.08        0.74
# SGDRegressor                                 0.86       0.88  0.08        0.03
# GradientBoostingRegressor                    0.86       0.88  0.08        1.02
# HuberRegressor                               0.86       0.88  0.08        0.07
# OrthogonalMatchingPursuit                    0.86       0.88  0.08        0.02
# OrthogonalMatchingPursuitCV                  0.86       0.88  0.08        0.02
# LinearSVR                                    0.86       0.88  0.08        0.15
# ElasticNetCV                                 0.86       0.88  0.08        0.25
# RANSACRegressor                              0.86       0.88  0.08        0.03
# LassoCV                                      0.86       0.88  0.08        0.20
# LassoLarsCV                                  0.85       0.88  0.08        0.10
# LassoLarsIC                                  0.85       0.88  0.08        0.04
# Ridge                                        0.85       0.88  0.08        0.02
# BayesianRidge                                0.85       0.88  0.08        0.03
# RidgeCV                                      0.85       0.88  0.08        0.03
# TransformedTargetRegressor                   0.85       0.88  0.08        0.04
# LinearRegression                             0.85       0.88  0.08        0.03
# DecisionTreeRegressor                        0.85       0.88  0.09        0.07
# LarsCV                                       0.85       0.87  0.09        0.07
# AdaBoostRegressor                            0.84       0.87  0.09        0.32
# ExtraTreeRegressor                           0.82       0.86  0.09        0.04
# Lars                                         0.81       0.85  0.10        0.05
# SVR                                          0.81       0.84  0.10        0.06
# PassiveAggressiveRegressor                   0.81       0.84  0.10        0.02
# TweedieRegressor                             0.80       0.84  0.10        0.12
# KNeighborsRegressor                          0.76       0.81  0.11        0.04
# GammaRegressor                               0.76       0.80  0.11        0.16
# PoissonRegressor                             0.68       0.74  0.13        0.12
# MLPRegressor                                 0.64       0.71  0.13        0.23
# ElasticNet                                  -0.23      -0.01  0.25        0.02
# DummyRegressor                              -0.23      -0.01  0.25        0.02
# LassoLars                                   -0.23      -0.01  0.25        0.03
# Lasso                                       -0.23      -0.01  0.25        0.02
# KernelRidge                                 -1.15      -0.76  0.33        0.05
# GaussianProcessRegressor                    -1.85      -1.33  0.38        0.14
# Calculate: Ang. Dist.
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                          0.74       0.79  0.08        0.63
# GradientBoostingRegressor                    0.74       0.78  0.08        0.91
# RandomForestRegressor                        0.73       0.78  0.08        1.74
# NuSVR                                        0.73       0.78  0.08        0.34
# LGBMRegressor                                0.73       0.78  0.08        0.35
# HistGradientBoostingRegressor                0.73       0.78  0.08        0.58
# XGBRegressor                                 0.73       0.78  0.08        0.63
# BaggingRegressor                             0.72       0.77  0.08        0.16
# SGDRegressor                                 0.71       0.77  0.09        0.03
# RANSACRegressor                              0.71       0.76  0.09        0.32
# HuberRegressor                               0.71       0.76  0.09        0.07
# LinearSVR                                    0.71       0.76  0.09        0.16
# DecisionTreeRegressor                        0.71       0.76  0.09        0.06
# OrthogonalMatchingPursuitCV                  0.71       0.76  0.09        0.03
# OrthogonalMatchingPursuit                    0.71       0.76  0.09        0.02
# LassoLarsCV                                  0.71       0.76  0.09        0.10
# LassoCV                                      0.71       0.76  0.09        0.16
# ElasticNetCV                                 0.71       0.76  0.09        0.17
# LarsCV                                       0.71       0.76  0.09        0.08
# AdaBoostRegressor                            0.70       0.76  0.09        0.26
# LassoLarsIC                                  0.70       0.76  0.09        0.04
# RidgeCV                                      0.70       0.75  0.09        0.04
# Ridge                                        0.70       0.75  0.09        0.02
# BayesianRidge                                0.70       0.75  0.09        0.02
# LinearRegression                             0.70       0.75  0.09        0.03
# TransformedTargetRegressor                   0.70       0.75  0.09        0.02
# Lars                                         0.69       0.75  0.09        0.04
# KNeighborsRegressor                          0.68       0.74  0.09        0.07
# ExtraTreeRegressor                           0.67       0.73  0.09        0.04
# TweedieRegressor                             0.66       0.72  0.09        0.18
# SVR                                          0.64       0.70  0.10        0.04
# PassiveAggressiveRegressor                   0.62       0.69  0.10        0.02
# GammaRegressor                               0.53       0.61  0.11        0.23
# PoissonRegressor                             0.48       0.57  0.12        0.13
# MLPRegressor                                 0.38       0.49  0.12        0.32
# KernelRidge                                  0.03       0.21  0.16        0.05
# ElasticNet                                  -0.23      -0.01  0.18        0.02
# DummyRegressor                              -0.23      -0.01  0.18        0.02
# LassoLars                                   -0.23      -0.01  0.18        0.03
# Lasso                                       -0.23      -0.01  0.18        0.02
# GaussianProcessRegressor                    -0.72      -0.41  0.21        0.13
# Calculate: Max Strain
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# LGBMRegressor                                0.66       0.72  0.11        0.40
# HistGradientBoostingRegressor                0.65       0.72  0.11        2.72
# GradientBoostingRegressor                    0.65       0.71  0.11        1.05
# ExtraTreesRegressor                          0.64       0.70  0.11        0.68
# XGBRegressor                                 0.64       0.70  0.11        0.58
# RandomForestRegressor                        0.64       0.70  0.11        1.59
# BaggingRegressor                             0.64       0.70  0.11        0.17
# AdaBoostRegressor                            0.62       0.69  0.12        0.28
# NuSVR                                        0.62       0.69  0.12        0.35
# TweedieRegressor                             0.59       0.66  0.12        0.08
# HuberRegressor                               0.59       0.66  0.12        0.16
# OrthogonalMatchingPursuitCV                  0.59       0.66  0.12        0.03
# SGDRegressor                                 0.59       0.66  0.12        0.03
# KNeighborsRegressor                          0.58       0.66  0.12        0.05
# OrthogonalMatchingPursuit                    0.58       0.66  0.12        0.03
# LinearSVR                                    0.58       0.66  0.12        0.15
# LassoLarsCV                                  0.58       0.65  0.12        0.12
# LassoLarsIC                                  0.58       0.65  0.12        0.04
# Ridge                                        0.58       0.65  0.12        0.02
# ElasticNetCV                                 0.57       0.65  0.12        0.30
# LassoCV                                      0.57       0.65  0.12        0.45
# BayesianRidge                                0.57       0.65  0.12        0.03
# RidgeCV                                      0.57       0.65  0.12        0.03
# TransformedTargetRegressor                   0.57       0.65  0.12        0.02
# LinearRegression                             0.57       0.65  0.12        0.03
# SVR                                          0.56       0.64  0.12        0.06
# DecisionTreeRegressor                        0.56       0.64  0.12        0.07
# ExtraTreeRegressor                           0.55       0.63  0.13        0.04
# RANSACRegressor                              0.51       0.60  0.13        0.30
# PassiveAggressiveRegressor                   0.49       0.58  0.13        0.02
# PoissonRegressor                             0.42       0.53  0.14        0.20
# MLPRegressor                                 0.36       0.48  0.15        0.38
# KernelRidge                                 -0.16       0.05  0.20        0.10
# LassoLars                                   -0.23      -0.01  0.21        0.05
# Lasso                                       -0.23      -0.01  0.21        0.04
# DummyRegressor                              -0.23      -0.01  0.21        0.02
# ElasticNet                                  -0.23      -0.01  0.21        0.02
# GaussianProcessRegressor                    -0.75      -0.43  0.25        0.13
# GammaRegressor                              -1.68      -1.19  0.28        0.15
# LarsCV                                   -1153.50    -944.16  2.84        0.15
# Lars                                     -1160.03    -949.52  3.00        0.07
# Calculate: G. Average
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# GradientBoostingRegressor                    0.86       0.89  0.08        1.03
# ExtraTreesRegressor                          0.86       0.89  0.08        0.77
# HistGradientBoostingRegressor                0.86       0.89  0.08        0.65
# RandomForestRegressor                        0.86       0.89  0.08        1.76
# LGBMRegressor                                0.86       0.89  0.08        0.36
# BaggingRegressor                             0.86       0.88  0.08        0.17
# XGBRegressor                                 0.86       0.88  0.08        0.81
# NuSVR                                        0.86       0.88  0.08        0.37
# SGDRegressor                                 0.85       0.88  0.08        0.03
# HuberRegressor                               0.85       0.88  0.08        0.08
# LassoLarsCV                                  0.85       0.88  0.08        0.09
# LarsCV                                       0.85       0.88  0.08        0.08
# LassoCV                                      0.85       0.88  0.08        0.16
# OrthogonalMatchingPursuit                    0.85       0.88  0.08        0.02
# ElasticNetCV                                 0.85       0.88  0.08        0.24
# OrthogonalMatchingPursuitCV                  0.85       0.88  0.08        0.02
# LassoLarsIC                                  0.85       0.88  0.08        0.04
# RANSACRegressor                              0.85       0.88  0.08        0.04
# Lars                                         0.85       0.88  0.08        0.05
# Ridge                                        0.85       0.88  0.08        0.02
# BayesianRidge                                0.85       0.88  0.08        0.03
# LinearSVR                                    0.85       0.88  0.08        0.15
# RidgeCV                                      0.85       0.88  0.08        0.03
# LinearRegression                             0.85       0.88  0.08        0.03
# TransformedTargetRegressor                   0.85       0.88  0.08        0.03
# AdaBoostRegressor                            0.85       0.87  0.08        0.33
# DecisionTreeRegressor                        0.84       0.87  0.08        0.09
# ExtraTreeRegressor                           0.83       0.86  0.09        0.04
# TweedieRegressor                             0.83       0.86  0.09        0.16
# PassiveAggressiveRegressor                   0.80       0.84  0.09        0.02
# SVR                                          0.80       0.84  0.09        0.04
# KNeighborsRegressor                          0.80       0.84  0.09        0.06
# GammaRegressor                               0.73       0.78  0.11        0.17
# PoissonRegressor                             0.71       0.76  0.11        0.18
# MLPRegressor                                 0.62       0.69  0.13        0.26
# DummyRegressor                              -0.23      -0.01  0.23        0.02
# ElasticNet                                  -0.23      -0.01  0.23        0.02
# LassoLars                                   -0.23      -0.01  0.23        0.03
# Lasso                                       -0.23      -0.01  0.23        0.03
# KernelRidge                                 -0.91      -0.56  0.29        0.05
# GaussianProcessRegressor                    -1.63      -1.16  0.34        0.14

# %%
for i, target in enumerate(target_columns):
    print(f'Calculate: {target}')
    print(pd.DataFrame(final_results[target],
                 columns = sorted_results[i].columns,
                 index =   sorted_results[i].index
    ).sort_values(by=['Adjusted R-Squared'], ascending=False).iloc[:1])
# Out:
# Calculate: C. Width
#                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# LGBMRegressor                0.66       0.72  0.12        0.43
# Calculate: Tot. Cracks
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# HistGradientBoostingRegressor                0.71       0.76  0.11        0.59
# Calculate: L. Average
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# HistGradientBoostingRegressor                0.77       0.81  0.10        0.60
# Calculate: Slope
#        Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# NuSVR                0.87       0.89  0.08        0.33
# Calculate: Tilt
#                      Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                0.86       0.89  0.08        0.68
# Calculate: Ang. Dist.
#                      Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                0.74       0.79  0.08        0.63
# Calculate: Max Strain
#                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# LGBMRegressor                0.66       0.72  0.11        0.40
# Calculate: G. Average
#                            Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# GradientBoostingRegressor                0.86       0.89  0.08        1.03
